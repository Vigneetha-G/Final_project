# %%
import pymongo
import json
import pandas as pd

# %%
client=pymongo.MongoClient("mongodb://localhost:27017")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Vigneetha-G/Final_project/main/bigdata.csv",low_memory=False)

# %%
df.tail()
# Out:
#         Complaint number                  Complaint filed against  \
# 102994            145433       UnitedHealthcare Insurance Company
# 102995            145435        Humana Health Plan of Texas, Inc.
# 102996            145436  Cigna Health and Life Insurance Company
# 102997            145437       UnitedHealthcare Insurance Company
# 102998            145438               ALLSTATE INDEMNITY COMPANY
#
#                  Complaint filed by  \
# 102994  Third Party Billing Service
# 102995  Third Party Billing Service
# 102996  Third Party Billing Service
# 102997  Third Party Billing Service
# 102998                  Third Party
#
#                                    Reason complaint filed Confirmed complaint  \
# 102994   Unsatisfactory Settle/Offer; Usual And Customary                  No
# 102995   Unsatisfactory Settle/Offer; Usual And Customary                  No
# 102996   Unsatisfactory Settle/Offer; Usual And Customary                  No
# ...

# %%
df.shape
# Out:
# (102999, 17)

# %%
data=df.to_dict(orient="records")

# %%
db=client["Bigdata"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Bigdata')

# %%
db.DataofinsuranceComplaints.insert_many(data)
# Out:
# InsertManyResult([ObjectId('662e76c8c5334bef395fda36'), ObjectId('662e76c8c5334bef395fda37'), ObjectId('662e76c8c5334bef395fda38'), ObjectId('662e76c8c5334bef395fda39'), ObjectId('662e76c8c5334bef395fda3a'), ObjectId('662e76c8c5334bef395fda3b'), ObjectId('662e76c8c5334bef395fda3c'), ObjectId('662e76c8c5334bef395fda3d'), ObjectId('662e76c8c5334bef395fda3e'), ObjectId('662e76c8c5334bef395fda3f'), ObjectId('662e76c8c5334bef395fda40'), ObjectId('662e76c8c5334bef395fda41'), ObjectId('662e76c8c5334bef395fda42'), ObjectId('662e76c8c5334bef395fda43'), ObjectId('662e76c8c5334bef395fda44'), ObjectId('662e76c8c5334bef395fda45'), ObjectId('662e76c8c5334bef395fda46'), ObjectId('662e76c8c5334bef395fda47'), ObjectId('662e76c8c5334bef395fda48'), ObjectId('662e76c8c5334bef395fda49'), ObjectId('662e76c8c5334bef395fda4a'), ObjectId('662e76c8c5334bef395fda4b'), ObjectId('662e76c8c5334bef395fda4c'), ObjectId('662e76c8c5334bef395fda4d'), ObjectId('662e76c8c5334bef395fda4e'), ObjectId('662e76c8c5334bef395f
# ...
